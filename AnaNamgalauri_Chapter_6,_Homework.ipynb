# %% [markdown]
# <a href="https://colab.research.google.com/github/ananamgalauri/Different-Calculations/blob/main/AnaNamgalauri_Chapter_6%2C_Homework.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
person = {
    'first_name': 'Angelina',
    'last_name': 'Jolie',
    'age': 49,
    'city': 'New York',

    }
first_name = person['first_name']
last_name = person['last_name']
age = person['age']
city = person ['city'] 

print(first_name)
print(last_name)
print(age)
print(city)

favorite_numbers = {
    'Elene': 5,
    'Giorgi': 9,
    'Tornike': 1,
    'Levani': 7,
    'Mariami': 6,

}

for names in favorite_numbers.keys():
    print(names)

for numbers in favorite_numbers.values():
    print(numbers)

    glossary = {
    'java script' : 'java script_codding',
    'c' : 'c_codding',
    'python' : 'python_codding',
    'computer': 'the machine we work with',
    'c++' : 'c++_coddding',
}

for words , meanings in glossary.items():
  print(words + ' : ' + meanings)


  rivers = {
    'Mississippi': 'America',
    'Amazon': 'America',
    'Mtkvari': 'Georgia',
}

for river, country in rivers.items():
  print('The ' + river + ' runs throught ' + country)
  print(river)
  print(country)



  favorite_languages = {
    'Elene' : 'Java Script',
    'Mariami' : 'python',
    'Tornike' : 'c',
    'Luka' : 'c',
}

for name in favorite_languages.keys():
  print(name.title())

new_people = {
    'Giorgi' : 'python',
    'Sopho' : 'c++',
    'Nini' : 'java',
    'Lika' : 'ruby',
    'Lela' : 'python',
}

for name in favorite_languages.keys():
  print(name.title() + ', thank you for taking the pole.')

for new_person in new_people:
    if new_person in favorite_languages:
        print(new_person + ', thank you for responding.')
    else:   print(new_person + ', we invite you to take poll.')


    pets = {
    'Elene': {
        'animal': 'Pig',
        'owner': 'Elene',
    },
    'Ani': {
        'animal': "Cat",
        'owner': 'Ani'
     },
}


favorite_places = {
    'Cat': ['close to owner', 'home'],
    'Dog': ['owner', 'house', 'with owner'],
    'Guinnea Pig': ['with owner'],
}
for name, places in favorite_places.items():
  print(name + ': ')
  for place in places:
    print('- ' + place)


    cities = {
    'Chicago': {
        'country': 'The United States',
        'population': '3 million',
        'fact': 'among the largest cities in the U.S',
    },
    'Almere': {
        'country': 'The Netherlands',
        'population': '1 million',
        'fact': 'one of the smallest cities in the Netherlands',
    },
    'Amsterdam': {
        'country': 'The Netherland',
        'population': '5 million',
        'fact': 'The most largest cities where people speak in Dutch',
    },
}

print(cities)
# Out:
# Angelina
# Jolie
# 49
# New York
# Elene
# Giorgi
# Tornike
# Levani
# Mariami
# 5
# 9
# 1
# 7
# 6
# java script : java script_codding
# c : c_codding
# python : python_codding
# computer : the machine we work with
# c++ : c++_coddding
# The Mississippi runs throught America
# Mississippi
# America
# The Amazon runs throught America
# Amazon
# America
# The Mtkvari runs throught Georgia
# Mtkvari
# Georgia
# Elene
# Mariami
# Tornike
# Luka
# Elene, thank you for taking the pole.
# Mariami, thank you for taking the pole.
# Tornike, thank you for taking the pole.
# Luka, thank you for taking the pole.
# Giorgi, we invite you to take poll.
# Sopho, we invite you to take poll.
# Nini, we invite you to take poll.
# Lika, we invite you to take poll.
# Lela, we invite you to take poll.
# Cat:
# - close to owner
# - home
# Dog:
# - owner
# - house
# - with owner
# Guinnea Pig:
# - with owner
# ...
